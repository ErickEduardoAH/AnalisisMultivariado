# %% [markdown]
# # 2.1 Principal component analysis
#
# ---
# > Erick Eduardo Aguilar Hernández:
# > * mat.ErickAguilar@ciencias.unam.mx
# > * isc.ErickAguilar@gmail.com
#
# ---

# %% [markdown]
# A principal component analysis is concerned with explained the variance  structure of a set of linear combinations whose general objetive its reduce data dimension and interpretation. Algebraically, principal components are a particular linear combination of p random variables $X_1,...,X_p$ that represent a change of basis obtained the new axes by the rotation of the original system. The new axes represent the directions with maximum variability and provides a simple and parsimonious description of the covariance structure.
#
# **Note**: Theire development desnt require a multivariate normal assumption, but principal components derived from multivariate normal populations have a usefull interpretations in terms of constant density ellipsoids.
#
# Lets the random vector $\mathbf{x}=(X_1,...,X_p) \in \mathbb{R}^p$ with covariance matrix $\mathbf{\Sigma}$ and the asociated ordered eigenvalues $\lambda_1 \geq ... \geq \lambda_p \geq 0$ and consider the following linear combinations given by the row vectors $\mathbf{a_i}$.
#
# $$
# \begin{cases}
# Y_{1}   & = a_{1 1} X_{1} + \cdots + a_{1 p} X_{p} = \mathbf{a_1 x} \\
# \vdots  & = \vdots \\
# Y_{p}   & = a_{p 1} X_{1} + \cdots + a_{p p} X_{p} = \mathbf{a_2 x} \\
# \end{cases}
# \\
# \begin{align*}
# \left[ \begin{array}{ccccc}
# Y_{1} \\
# \vdots  \\
# Y_{p} \end{array} \right]
# & =
# \left[ \begin{array}{ccccc}
# a_{1 1} & \cdots & a_{1 p} \\
# \vdots  & \ddots & \vdots \\
# a_{p 1} & \cdots & a_{p p} \end{array} \right]
# \left[ \begin{array}{ccccc}
# X_{1} \\
# \vdots  \\
# X_{p} \end{array} \right]\\
# \\
# \textbf{y} & =\textbf{Ax} \\
# \end{align*}
# $$
#
# Using the last results, we have for the ith row $\mathbf{a_i}$ of $\mathbf{A}$:
#
# $$
# V(Y_i) = \mathbf{a_i \Sigma a_i'}\\
# Cov(Y_i,Y_j) = \mathbf{a_i \Sigma a_j'}\\
# $$
#
# We know that $Cov(\mathbf{y}) = \mathbf{A \Sigma A'}$ but the covariances from this expression could be increased by multiplying any constant by $\mathbf{A}$, to quote this indeterminacy it's necesary to restrict to coeficient vectors of lenght 1. The principal components are those uncorrelated linear combinations $Y_1,...Y_p$ whose variances are larger as possible such that $Y_i$ is independen from $Y_j$ or $i \neq j$.
#
# * First principal component: linear combination $\mathbf{a_1 x}$ that maximizes $V(\mathbf{a_1 x})$ subject to $<\mathbf{a_1,a_1}>$=1
# * Second principal component: linear combination $\mathbf{a_1 x}$ that maximizes $V(\mathbf{a_1 x})$ subject to $<\mathbf{a_2,a_2}>$=1 and $<\mathbf{a_1,a_2}>$=0
# $$\vdots$$
# * The ith principal component = linear combination $\mathbf{a_i x}$ that maximizes $V(\mathbf{a_i x})$ subject to $<\mathbf{a_i,a_i}$>=1 and $<\mathbf{a_i,a_k}>$=0 for $k < i$
#
# Sinces the covariance matrix $\mathbf{\Sigma}$ it's orthogonally diagonalizable, $\mathbf{\Sigma}=\mathbf{\Gamma \Lambda \Gamma'}$, If  $\lambda_k \mathbf{\gamma_k}$ it's a eigen vector asociated to $\mathbf{\Sigma}$, it's satisfy the principal components restrictions:
#
# 1. $<\mathbf{\gamma_i',\gamma_i}$>=1
# 1. $<\mathbf{\gamma_i',\gamma_0}$>=0 for $k < i$
#
# It remains to prove that variance as function of $\mathbf{a}$ it's quoted and the eigenvectors maximize the variance. Considering the restrictions that $\mathbf{a}$ must satify it clear that $\mathbf{a' \Sigma a}$ and $\mathbf{\frac{a' \Sigma a}{a' a}}$ have the same maximum where $\mathbf{\frac{a' \Sigma a}{a' a}}$ eliminates the problem of the constant. Considering the next transformation $\mathbf{b}=\mathbf{\Gamma' a}$ we have:
#
# $$
# \begin{align*}
# \mathbf{\frac{a' \Sigma a}{a' a}} &= \mathbf{\frac{a' \Gamma \Lambda \Gamma' a}{a' a}}\\
# &= \mathbf{\frac{b' \Lambda b}{b' b}} \\
# \mathbf{\frac{a' \Sigma a}{aa'}} &= \frac{\sum_{k=1}^{p} \lambda_k b_k^2}{\sum_{k=1}^{p}b_k^2}\\
# \end{align*}
# $$
#
# Since $\lambda_p \leq \lambda_{p-1} \leq \dots \leq \lambda_i \leq \dots \leq \lambda_1$ for the ordered ith eigenvalue $\lambda_i$ the variance as function of function $\mathbf{a}$ it's quoted.
#
# $$
# \begin{cases}
# \lambda_i b_1^2 \leq \lambda_i b_1^2  \\
# \lambda_{i-1} b_1^2 \leq \lambda_i b_1^2  \\
# \vdots  \\
# \lambda_p b_p^2 \leq \lambda_1 b_p^2  \\
# \end{cases}
# $$
#
#
# $$
# \begin{align*}
# \lambda_i b_1^2 + \lambda_{i-1} b_2^2 + \dots +\lambda_p b_p^2 &\leq \lambda_i b_1^2 + \lambda_i b_2^2 + \dots +\lambda_i b_p^2\\
# \frac{\sum_{k=i}^{p} \lambda_k b_k^2}{\sum_{k=i}^{p}b_k^2} &\leq \frac{\sum_{k=i}^{p} \lambda_i b_k^2}{\sum_{k=i}^{p}b_k^2}\\
# \frac{\sum_{k=i}^{p} \lambda_k b_k^2}{\sum_{k=i}^{p}b_k^2} &\leq \lambda_i \frac{\sum_{k=i}^{p} b_k^2}{\sum_{k=i}^{p}b_k^2}\\
# \frac{\sum_{k=i}^{p} \lambda_k b_k^2}{\sum_{k=i}^{p}b_k^2} &\leq \lambda_i \\
# \end{align*}
# $$
#
# In particular for $\lambda_1$ we have that any variance for any linear combinations with coeficients given by $\mathbf{a}$ it's qouted by the first eigenvalue.
#
# $$
# \begin{align*}
# \frac{\sum_{k=1}^{p} \lambda_k b_k^2}{\sum_{k=1}^{p}b_k^2}&\leq \lambda_1 \\
# \mathbf{\frac{a' \Sigma a}{a' a}}&\leq \lambda_1 \\
# \end{align*}
# $$
#
# If some value of $\mathbf{x}$ the function reach the quote, then this point its a critical point and maximize the function, so replacing the first eigenvalue $\gamma_1$:
#
# $$
# \begin{align*}
# \mathbf{\frac{a \Sigma a'}{a' a}} &= \mathbf{\frac{\gamma_i' \Sigma \gamma_i}{\gamma_i' \gamma_i}} \\
# &= \mathbf{\gamma_i' \Sigma \gamma_i} \\
# &= \mathbf{\gamma_i'} \lambda_i \mathbf{\gamma_i} \\
# &= \lambda_i \\
# \mathbf{\gamma_i' \Sigma \gamma_i} &= \lambda_i \\
# V(\mathbf{\gamma_i' x}) &= \lambda_i \\
# \end{align*}
# $$
#
# If we take $\mathbf{a}=\mathbf{\gamma_i'}$ this transformation reach the maximum variance for $Y_i = \mathbf{\gamma_i' x}$, so $\mathbf{\gamma_i'}$ its the ith principal component, because these are the linear combinations that maximizes the variances and produce new independent variables.
#
# ![pca gif](static/pca2gif.gif)
#
# So the principal components (PCA) transformation of $\mathbf{x}$ with covariance matrix given by $Cov(\mathbf{x})=\mathbf{\Sigma}=\mathbf{\Gamma \Lambda \Gamma'}$  its:
#
#
# $$
# \begin{cases}
# \begin{align*}
# PCA_1 & = \gamma_{1 1} X_{1} + \cdots + \gamma_{1 p} X_{p} = \mathbf{\gamma_1' x} \\
# \vdots & = \vdots \\
# PCA_p & = \gamma_{p 1} X_{1} + \cdots + \gamma_{p p} X_{p} = \mathbf{\gamma_p' x} \\
# \end{align*}
# \end{cases}
# $$
#
#
# $$
# \begin{align*}
# \begin{bmatrix}
#     PCA_1 \\
#      \vdots\\
#     PCA_p \\
# \end{bmatrix}&=
# \begin{bmatrix}
#     \text{-} & \mathbf{\gamma_1} & \text{-} \\
#     & \vdots &\\
#     \text{-} & \mathbf{\gamma_p} & \text{-} \\
# \end{bmatrix}
# \begin{bmatrix}
#     X_1 \\
#      \vdots\\
#     X_p \\
# \end{bmatrix}\\
# PCA(\mathbf{x}) &= \mathbf{\Gamma' x}  \\
# \end{align*}
# $$
#
#
# If we have a data matrix $\mathbf{X}_{n \times p}$ with $\mathbf{S} = \mathbf{\Gamma \Lambda \Gamma'}$ the pc transformations for this matrix it's given by:
#
# $$
# PCA(\mathbf{X}_{n \times p}) = \mathbf{X}_{n \times p}\mathbf{\Gamma}
# $$
#
# **Explained variability ratios:**
#
# From the spectral analysis we have
#
# $$
# \begin{align*}
# \Sigma&=\sum_{k=1}^p\lambda_k\mathbf{\gamma_k\gamma_k'}\\
# tr[ \Sigma ] &= tr \left[ \sum_{k=1}^p\lambda_k\mathbf{\gamma_k\gamma_k'} \right]\\
# &= \sum_{k=1}^p \lambda_k tr \left[ \mathbf{\gamma_k\gamma_k'} \right]\\
# &= \sum_{k=1}^p \lambda_k tr \left[ \mathbf{\gamma_k'\gamma_k} \right]\\
# tr[ \Sigma ] &= \sum_{k=1}^p \lambda_k \\
# \end{align*}
# $$
#
# The percentage of variability that contributes the i-th component is given by:
#
# $$\frac{\lambda_i}{tr[\mathbf{\Sigma}]}=\frac{\lambda_i}{\lambda_1+\dots+\lambda_p}$$
#
# The cumulated percentaje of variability untill the i-th component is:
#
# $$\frac{\sum_{k=1}^{i}\lambda_k}{tr[\mathbf{\Sigma}]}=\frac{\lambda_1+\lambda_i}{\lambda_1+\dots+\lambda_p}$$
#
#
# The number of principal components is taken so that the accumulated explained variability is close to a value specified by the scientist, for example 80%. On the other hand, if the representation of is stabilized from a certain eigenvalue, then increase the dimension hardly provides more explained variability.
#
#
#
# # Biplot
# ---
#
# A biplot its a generalization of the simple two-variable scatterplot. A biplot allows information on both samples and variables of a data matrix to be displayed graphically. Samples are displayed as points while variables are displayed either as vectors. The prefix "bi" refers to the overlap, in the same plot variables and observtions.
#
# A biplot for a matrix $\mathbf{X_{n \times p}}$ is a graphic representation by p vectors (markers) $v_1,\dots,v_p$ for the n rows $u_1,\dots, u_n$ of $\mathbf{X}$ such that the element $x_{ij} \approx \mathbf{v_i u_j'}$ as well as possible.
#
# $$\mathbf{X \approx UV'}$$
#
# For the euclidean space $\mathbb{R^2}$ if the matrix $\mathbf{X}$ has range 2 the aproximations will be exactly in other case it will be an aproximation. Consider the PCA transformation:
#
# $$
# \begin{align*}
# \mathbf{\Gamma' x}&=\mathbf{y}\\
# \mathbf{x} &=\mathbf{\Gamma y}\\
# \end{align*}
# \\
# \begin{cases}
# X_{1}   & = \gamma_{1 1} Y_{1} + \cdots + \gamma_{p 1} Y_{p}\\
# \vdots  & = \vdots \\
# X_{p}   & = \gamma_{1 p} Y_{1} + \cdots + \gamma_{p p} Y_{p}\\
# \end{cases}
# $$
#
#
# Taking the first i ordered components.
#
# $$
# \begin{cases}
# \begin{align*}
# X_{1}   & \approx \gamma_{1 1} Y_{1} + \cdots + \gamma_{i 1} Y_{i}\\
# \vdots  & \approx \vdots \\
# X_{p}   & \approx \gamma_{1 p} Y_{1} + \cdots + \gamma_{i p} Y_{i}\\
# \end{align*}
# \end{cases}
# $$
#
# The markers will be the first columns of the variables transformed to the new space and the vectors the first columns of the base change matrix. This approximation depends on the number of principal components taken (usually 2), the resolution of the biplot its given by the cumulated percentaje of variability untill the i-th component.
#
#
# **Example** [Principal component analysis manual]
#
# Compute the pca transformation for the following data matrix $\mathbf{X}$
#
# $$
# \mathbf{X}=
# \begin{bmatrix}
#     2 & 1 \\
#     1 & 2 \\
#     -1 & 1 \\
#     -2 & -1 \\
#     -1 & -2 \\
#     1 & -1\\
# \end{bmatrix}
# $$
#
# For this matrix the spectral decomposition of the covariance matrix its given by
#
# $$
# \mathbf{\Gamma \Lambda \Gamma'} = \begin{bmatrix} \frac{1}{\sqrt{2}} & \frac{-1}{\sqrt{2}} \\ \frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \\ \end{bmatrix} \begin{bmatrix} 3 & 0 \\ 0 & 1 \\ \end{bmatrix} \begin{bmatrix} \frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \\ \frac{-1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \\ \end{bmatrix} = \begin{bmatrix} 2 & 1 \\ 1 & 2 \\ \end{bmatrix} = \mathbf{S}
# $$
#
# The principal components transformation of $\mathbf{X}$ is:
#
# $$
# PCA(\mathbf{X})=\mathbf{X \Gamma} =
# \begin{bmatrix}
#     2 & 1 \\
#     1 & 2 \\
#     -1 & 1 \\
#     -2 & -1 \\
#     -1 & -2 \\
#     1 & -1\\
# \end{bmatrix}
#     \begin{bmatrix} \frac{1}{\sqrt{2}} & \frac{-1}{\sqrt{2}} \\ \frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}} \\
# \end{bmatrix}
# =
# \begin{bmatrix}
#     \frac{3}{\sqrt{2}} & \frac{-1}{\sqrt{2}} \\
#     \frac{3}{\sqrt{2}} & \frac{1}{\sqrt{2}} \\
#     0 & \frac{2}{\sqrt{2}} \\
#     \frac{-3}{\sqrt{2}} & \frac{1}{\sqrt{2}} \\
#     \frac{-3}{\sqrt{2}} & \frac{-1}{\sqrt{2}} \\
#     0 & \frac{-2}{\sqrt{2}}\\
# \end{bmatrix}
# $$

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
from sklearn.decomposition import PCA
from IPython.display import display, HTML

pd.set_option('max_colwidth',100)
warnings.filterwarnings('ignore')
plt.style.use('ggplot')

# %%
run MvaUtils.py

# %%
X = np.matrix([[2,1],[1,2],[-1,1],[-2,-1],[-1,-2],[1,-1]])
S = (1/6)*np.dot(X.transpose(),X)
Lambda,Gamma=diagonalize(S)
pcaX = np.dot(X,Gamma)

print('X\n',X)
print('Gamma\n',Gamma)
print('Lambda\n',np.diag(Lambda))
print('Gamma\'\n',Gamma.transpose())
print('PCA(X)\n',pcaX)
X_df = pd.DataFrame(pcaX,columns=['pc1','pc2'])
display(X_df.cov())
# Out:
# X
#  [[ 2  1]
#  [ 1  2]
#  [-1  1]
#  [-2 -1]
#  [-1 -2]
#  [ 1 -1]]
# Gamma
#  [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]
# Lambda
#  [[3. 0.]
#  [0. 1.]]
# Gamma'
#  [[ 0.70710678  0.70710678]
#  [-0.70710678  0.70710678]]
# PCA(X)
#  [[ 2.12132034 -0.70710678]
#  [ 2.12132034  0.70710678]
#  [ 0.          1.41421356]
#  [-2.12132034  0.70710678]
#  [-2.12132034 -0.70710678]
#  [ 0.         -1.41421356]]
#               pc1           pc2
# pc1  3.600000e+00 -8.781775e-18
# pc2 -8.781775e-18  1.200000e+00

# %%
x = X.transpose().tolist()[0]
y = X.transpose().tolist()[1]
pcax = pcaX.transpose().tolist()[0]
pcay = pcaX.transpose().tolist()[1]
plt.figure(figsize=(10,10))
plt.fill(x, y,alpha=0.5,)
plt.fill(pcax,pcay,alpha=0.5)

# %% [markdown]
# ___
#
# **Example** [Principal component analysis of normal disttributions]
#
# Lets generate a multivariated normal sample with parameters
#
# $$ N \left(\mathbf{\mu} = \begin{bmatrix} 0 \\ 0 \end{bmatrix} \mathbf{\Sigma}=\begin{bmatrix} 5 & 5 \\ 5 & 10 \end{bmatrix} \right) $$

# %%
normalSamplePD = getMvNormalSample([0,0],[[5,-5],[-5,10]],n=5000)
plt.figure(figsize=(15,15))
scatterPlot(plt,normalSamplePD,'x1','x2','Black',color='Black',alpha=0.6)

# %%
normalSamplePD.cov()
# Out:
#           x1        x2
# x1  4.894608 -4.814753
# x2 -4.814753  9.688468

# %% [markdown]
# Applying a PCA over the generated data matrix using Sklearn

# %%
from sklearn.decomposition import PCA

pcaNormalCols = ['pc'+str(i+1) for i in range(0,2)]
print(pcaNormalCols)
pcaNormalSampleModel = PCA(n_components=2).fit(normalSamplePD.values)
pcaNormalSampleMatrix = pd.DataFrame(pcaNormalSampleModel.components_.transpose(),columns=pcaNormalCols)

print('PCA Transformation Matrix:\n')
display(pcaNormalSampleMatrix)
print('PCA Eigenvalues:\n',pcaNormalSampleModel.explained_variance_)

plt.figure(figsize=(5,5))
screePlot(plt,pcaNormalSampleModel.explained_variance_ratio_)
# Out:
# ['pc1', 'pc2']
# PCA Transformation Matrix:
#         pc1       pc2
# 0 -0.526470  0.850194
# 1  0.850194  0.526470
# PCA Eigenvalues:
#  [12.6699313   1.91314429]
#    explained variance
# 0            0.868811
# 1            0.131189

# %% [markdown]
# Visualizing principal componented of data

# %%
def plotProjectedBase(plt,components,projectedCanonicalsPD,colums,axesColor='blue',axesAlpha=1,arrowWidth=1.0,\
                      arrowColor='black',arrowAlpha=1,head_width=0.04,head_length=0.1,shift=2/100):
    M = np.matrix(projectedCanonicalsPD[components].values)
    rows,cols = M.T.shape
    maxes = np.amax(abs(M), axis = 0)
    t = np.linspace(-1000, 1000, 100)
    plt.xlabel(components[0])
    plt.ylabel(components[1])
    for i,l in enumerate(range(0,cols)):
        plt.axes().arrow(0,0,M[i,0],M[i,1],head_width=head_width,head_length=head_length,\
                         color=arrowColor,alpha=arrowAlpha,linewidth=arrowWidth)
        plt.annotate(colums[i],xy=(M[i,0],M[i,1]),xytext=(M[i,0]+shift,M[i,1]+shift),\
                         weight='bold',color=arrowColor)
        plt.plot(t*M[i,0],t*M[i,1],color=axesColor,alpha=axesAlpha)        
    plt.plot(0,0,'ok')
    plt.grid(b=True, which='major')

# %%
plt.figure(figsize=(15,15))
plt.axis([-10,10,-10,10])
plotProjectedBase(plt,['pc1','pc2'],pcaNormalSampleMatrix,['x1','x2'])
scatterPlot(plt,normalSamplePD,'x1','x2','Black',color='Black')

# %% [markdown]
# Transforming the data to the new reference system

# %%
pcaNormalDataPD = pd.DataFrame(\
                    data=pcaNormalSampleModel.transform(normalSamplePD.values),\
                    columns=pcaNormalCols)

plt.figure(figsize=(15,15))
scatterPlot(plt,normalSamplePD,'x1','x2','Black',color='Black')
scatterPlot(plt,pcaNormalDataPD,'pc1','pc2','Blue',color='Blue')

# %%
plt.figure(figsize=(15,15))
plt.axis([-10,10,-10,10])
scatterPlot(plt,pcaNormalDataPD,'pc1','pc2','Red',color='Blue')

# %%
pcaNormalDataPD.cov()
# Out:
#               pc1           pc2
# pc1  1.266993e+01  5.287495e-16
# pc2  5.287495e-16  1.913144e+00

# %% [markdown]
# ___
#
# **Example** [Principal component analysis of iris plants]
#
# Loading data

# %%
features = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
keys = ['Species']
irisPath = 'DataSets/Iris.csv'
irisPD = pd.read_csv(irisPath)
irisPD
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Centering and transforming the centered dataset in to PCA transformation

# %%
from sklearn.preprocessing import StandardScaler

X = irisPD.loc[:,features].values
Y = irisPD.loc[:,keys].values

centeredIrisX = StandardScaler(with_mean=True,with_std=False).fit_transform(X)
pd.DataFrame(centeredIrisX)
# Out:
#             0      1         2         3
# 0   -0.743333  0.446 -2.358667 -0.998667
# 1   -0.943333 -0.054 -2.358667 -0.998667
# 2   -1.143333  0.146 -2.458667 -0.998667
# 3   -1.243333  0.046 -2.258667 -0.998667
# 4   -0.843333  0.546 -2.358667 -0.998667
# ..        ...    ...       ...       ...
# 145  0.856667 -0.054  1.441333  1.101333
# 146  0.456667 -0.554  1.241333  0.701333
# 147  0.656667 -0.054  1.441333  0.801333
# 148  0.356667  0.346  1.641333  1.101333
# 149  0.056667 -0.054  1.341333  0.601333
#
# [150 rows x 4 columns]

# %%
from sklearn.decomposition import PCA
k=4
pcaIrisCols = ['pc'+str(i+1) for i in range(0,k)]
pcaIrisModel = PCA(n_components=k).fit(centeredIrisX)
transformedIrisDataPD = pd.DataFrame(data=pcaIrisModel.transform(centeredIrisX),columns=pcaIrisCols)
pcaIrisPD = pd.concat([irisPD,transformedIrisDataPD],axis=1)
pcaIrisPD[:5]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
#
#         pc1       pc2       pc3       pc4
# 0 -2.684207  0.326607 -0.021512  0.001006
# 1 -2.715391 -0.169557 -0.203521  0.099602
# 2 -2.889820 -0.137346  0.024709  0.019305
# 3 -2.746437 -0.311124  0.037672 -0.075955
# 4 -2.728593  0.333925  0.096230 -0.063129

# %%
pcaIrisMatrix = pd.DataFrame(pcaIrisModel.components_.transpose(),columns=pcaIrisCols)
print('PCA Transformation Matrix:\n')
display(pcaIrisMatrix)
print('PCA Eigenvalues:\n',pcaIrisModel.explained_variance_)
print('PCA Explainded variance:\n',pcaIrisModel.explained_variance_/sum(pcaIrisModel.explained_variance_))
# Out:
# PCA Transformation Matrix:
#         pc1       pc2       pc3       pc4
# 0  0.361590  0.656540 -0.580997  0.317255
# 1 -0.082269  0.729712  0.596418 -0.324094
# 2  0.856572 -0.175767  0.072524 -0.479719
# 3  0.358844 -0.074706  0.549061  0.751121
# PCA Eigenvalues:
#  [4.22484077 0.24224357 0.07852391 0.02368303]
# PCA Explainded variance:
#  [0.92461621 0.05301557 0.01718514 0.00518309]

# %%
plt.figure(figsize=(5,5))
screePlot(plt,pcaIrisModel.explained_variance_ratio_)
# Out:
#    explained variance
# 0            0.924616
# 1            0.053016
# 2            0.017185
# 3            0.005183

# %%
smpc = sns.pairplot(pcaIrisPD[keys+pcaIrisCols[:2]],hue="Species",diag_kind='hist',palette="plasma")

# %%
labels = ['Iris-versicolor','Iris-virginica']
overlapedHitograms(plt,pcaIrisPD,pcaIrisCols,'Species',labels,bins=15)

# %% [markdown]
# ### Scree Plot
# ___
# Obataining and ploting the percetage of expained variability.

# %%
plt.figure(figsize=(7,7))
screePlot(plt,pcaIrisModel.explained_variance_ratio_)
# Out:
#    explained variance
# 0            0.924616
# 1            0.053016
# 2            0.017185
# 3            0.005183

# %% [markdown]
# Labeling the transformed dataset with the original sub set which comes from.

# %% [markdown]
# ### Biplot
# ___
# Ploting the transformed dataset and the projection of the canonical base taking only 2 components in to two dimension space.

# %%
col_1,col_2='pc1','pc2'
alpha=0.05
df=2
plt.figure(figsize=(15,10))
plt.axis([-5.4,5,-1.7,1.7])

irisSetosaPD = pcaIrisPD[pcaIrisPD['Species']=='Iris-setosa']
irisVersicolorPD = pcaIrisPD[pcaIrisPD['Species']=='Iris-versicolor']
irisVirginicaPD = pcaIrisPD[pcaIrisPD['Species']=='Iris-virginica']


scatterPlot(plt,irisSetosaPD,col_1,col_2,'Green',color='black',alpha=0.2)
summarySetosaPD = getProbabilityDensityContour(plt,irisSetosaPD,[col_1,col_2],alpha,df,\
                                             color='Green',name='Iris-setosa')

scatterPlot(plt,irisVersicolorPD,col_1,col_2,'Blue',color='black',alpha=0.2)
summaryVersicolorPD = getProbabilityDensityContour(plt,irisVersicolorPD,[col_1,col_2],alpha,df,\
                                             color='Blue',name='Iris-versicolor')

scatterPlot(plt,irisVirginicaPD,col_1,col_2,'Red',color='black',alpha=0.2)
summaryVirginicaPD = getProbabilityDensityContour(plt,irisVirginicaPD,[col_1,col_2],alpha,df,\
                                             color='Red',name='Iris-virginica')

plotProjectedBase(plt,[col_1,col_2],pcaIrisMatrix[[col_1,col_2]],features)

plt.show()
display(summarySetosaPD)
display(summaryVersicolorPD)
display(summaryVirginicaPD)
# Out:
#                       Summary  \
# 0                        Mean
# 1           Covariance matrix
# 2                 EigenValues
# 3                EigenVectors
# 4                  Confidence
# 5  Chi-squared critical value
#
#                                                         Iris-setosa
# 0                        [-2.6408407583131277, 0.19051995278137251]
# 1    [[[[[0.04874538 0.05704879]]]], [[[[0.05704879 0.21910567]]]]]
# 2                       [0.23644489801176308, 0.031406156302396154]
# 3  [[[[[ 0.29080169 -0.95678335]]]], [[[[0.95678335 0.29080169]]]]]
# 4                                                              0.95
# 5                                                           5.99146
#                       Summary  \
# 0                        Mean
# 1           Covariance matrix
# 2                 EigenValues
# 3                EigenVectors
# 4                  Confidence
# 5  Chi-squared critical value
#
#                                                       Iris-versicolor
# 0                          [0.5319926168946606, -0.24402963305499767]
# 1      [[[[[0.35611595 0.19839956]]]], [[[[0.19839956 0.18447935]]]]]
# 2                         [0.48646232369423315, 0.054132979856909666]
# 3  [[[[[-0.83576441  0.54908821]]]], [[[[-0.54908821 -0.83576441]]]]]
# 4                                                                0.95
# 5                                                             5.99146
#                       Summary  \
# 0                        Mean
# 1           Covariance matrix
# 2                 EigenValues
# 3                EigenVectors
# 4                  Confidence
# 5  Chi-squared critical value
#
#                                                        Iris-virginica
# 0                            [2.108848141418467, 0.05350968027362514]
# 1      [[[[[0.49894371 0.27527719]]]], [[[[0.27527719 0.23230706]]]]]
# 2                           [0.6714869712213798, 0.05976380783349097]
# 3  [[[[[-0.8473128   0.53109417]]]], [[[[-0.53109417 -0.8473128 ]]]]]
# 4                                                                0.95
# 5                                                             5.99146

# %% [markdown]
# ____
#
# **Example**
# The importance of dimensional reduction. The following data set contains samples of two types of wines (red wine and white wine) both datasets share the following same characteristics:
#
# * fixedAcidity
# * volatileAcidity
# * citricAcid
# * residualSugar
# * chlorides
# * freeSulfurDioxide
# * totalSulfurdioxide
# * density
# * pH
# * sulphates
# * alcohol
# * quality
# label:
# * 1 If the row belongs to red wine sample
# *0 If the row belongs to white wine sample
#
# The objective is try to determine if there are significative differences between the observations of red and white wine.

# %%
kw=12
labelCol = 'label'
whiteWinnePath = 'DataSets/winequalityWhite.csv'
redWinnePath = 'DataSets/winequalityRed.csv'

# %%
whiteWinePD = pd.read_csv(whiteWinnePath)
redWinePD = pd.read_csv(redWinnePath)
features = list(redWinePD.columns)
display(whiteWinePD[:3])
display(redWinePD[:3])
# Out:
#    fixedAcidity  volatileAcidity  citricAcid  residualSugar  chlorides  \
# 0           7.0             0.27        0.36           20.7      0.045
# 1           6.3             0.30        0.34            1.6      0.049
# 2           8.1             0.28        0.40            6.9      0.050
#
#    freeSulfurDioxide  totalSulfurdioxide  density    pH  sulphates  alcohol  \
# 0               45.0               170.0   1.0010  3.00       0.45      8.8
# 1               14.0               132.0   0.9940  3.30       0.49      9.5
# 2               30.0                97.0   0.9951  3.26       0.44     10.1
#
#    quality
# 0        6
# 1        6
# 2        6
#    fixedAcidity  volatileAcidity  citricAcid  residualSugar  chlorides  \
# 0           7.4             0.70        0.00            1.9      0.076
# 1           7.8             0.88        0.00            2.6      0.098
# 2           7.8             0.76        0.04            2.3      0.092
#
#    freeSulfurDioxide  totalSulfurdioxide  density    pH  sulphates  alcohol  \
# 0               11.0                34.0   0.9978  3.51       0.56      9.4
# 1               25.0                67.0   0.9968  3.20       0.68      9.8
# 2               15.0                54.0   0.9970  3.26       0.65      9.8
#
#    quality
# 0        5
# 1        5
# 2        5

# %%
pcaWineCols = ['pc'+str(i+1) for i in range(0,kw)]
wineX = pd.concat([whiteWinePD,redWinePD]).loc[:,features].values
redWineX = redWinePD.loc[:,features].values
whiteWineX = whiteWinePD.loc[:,features].values
wineX
# Out:
# array([[ 7.   ,  0.27 ,  0.36 , ...,  0.45 ,  8.8  ,  6.   ],
#        [ 6.3  ,  0.3  ,  0.34 , ...,  0.49 ,  9.5  ,  6.   ],
#        [ 8.1  ,  0.28 ,  0.4  , ...,  0.44 , 10.1  ,  6.   ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  6.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  5.   ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  6.   ]])

# %%
kw=12
centeredWineX = StandardScaler(with_mean=True,with_std=False).fit_transform(wineX)
pcaWineModel = PCA(n_components=kw).fit(centeredWineX)
pcaWineMatrix = pd.DataFrame(pcaWineModel.components_.transpose(),columns=pcaWineCols)
pcaRedWineDataPD = pd.DataFrame(pcaWineModel.transform(redWineX),columns=pcaWineCols)
pcaWhiteWineDataPD = pd.DataFrame(pcaWineModel.transform(whiteWineX),columns=pcaWineCols)

# %%
print('PCA Transformation Matrix:\n')
display(pcaWineMatrix)
plt.figure(figsize=(5,5))
screePlot(plt,pcaWineModel.explained_variance_ratio_)
# Out:
# PCA Transformation Matrix:
#          pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0  -0.007408 -0.005372  0.023851  0.713392  0.693897  0.056831  0.033895
# 1  -0.001184 -0.000787  0.000905  0.024002 -0.017972  0.042067  0.620447
# 2   0.000487 -0.000247  0.001922  0.024029  0.050975 -0.003093 -0.400578
# 3   0.041020  0.018628  0.995216 -0.070501  0.035551  0.034963  0.005803
# 4  -0.000168  0.000067  0.000177  0.009905 -0.003428 -0.002405  0.038288
# 5   0.230482  0.972619 -0.027125  0.010812 -0.000679  0.006097  0.000013
# 6   0.972167 -0.231395 -0.035854  0.002261  0.007397  0.000039  0.001726
# 7   0.000002  0.000001  0.000461  0.001439 -0.000171 -0.000473  0.005184
# 8  -0.000656  0.000648 -0.006911 -0.027614 -0.037713 -0.005698  0.572126
# 9  -0.000704  0.000347 -0.001936  0.022357  0.016722 -0.019031  0.350956
# 10 -0.005452  0.002879 -0.082596 -0.609807  0.585665  0.527017  0.016874
# 11 -0.000533  0.009152 -0.008792 -0.334064  0.411764 -0.845922  0.033488
#
#          pc8       pc9      pc10      pc11          pc12
# 0  -0.027296 -0.050104 -0.035928  0.000587 -1.023684e-03
# 1  -0.376972  0.342037  0.590742 -0.065542 -2.179783e-03
# 2   0.500643 -0.045735  0.762770 -0.042356 -6.608529e-05
# 3   0.003704 -0.002709 -0.002050  0.000670 -3.790783e-04
# 4   0.038209  0.068859  0.054293  0.994605 -5.546245e-03
# 5  -0.000578  0.000254  0.000360 -0.000132  9.297818e-08
# 6  -0.000193  0.000053 -0.000126  0.000134  4.201326e-06
# 7   0.002613 -0.001381  0.001268  0.005286  9.999661e-01
# 8   0.328527 -0.748519  0.044160  0.014871 -4.959079e-03
# 9   0.704033  0.559720 -0.249775 -0.065897 -2.259136e-03
# 10  0.004640  0.004199 -0.011019  0.008869  1.138269e-03
# 11 -0.037533  0.008571  0.022394  0.001039  5.734627e-05
#     explained variance
# 0         9.535529e-01
# 1         4.062238e-02
# 2         4.825567e-03
# 3         4.944326e-04
# 4         3.466891e-04
# 5         1.364109e-04
# 6         8.679473e-06
# 7         5.696002e-06
# 8         4.135561e-06
# 9         2.935694e-06
# 10        2.194428e-07
# 11        1.592604e-10

# %%
plt.figure(figsize=(15,15))
scatterPlot(plt,pcaWhiteWineDataPD,'pc1','pc2','Blue',color='Black',alpha=0.5)
scatterPlot(plt,pcaRedWineDataPD,'pc1','pc2','Red',color='Black',alpha=0.5)
plt.show()

# %% [markdown]
# Something is going wrong with the componentes. A fast inspection reveals that there are some columns with high variance, these columns are absorbing the covariance of the components, this happens because all columns are not in same metric scale, standarizing the columns could be a good transformation in oder to avoid some columns absorbs all the explained variance

# %%
plt.figure(figsize=(17,10))
pd.concat([whiteWinePD,redWinePD]).boxplot()

# %% [markdown]
# Standarizing the data with skalearn preprocesing module
#
# Check https://scikit-learn.org/stable/modules/preprocessing.html#standardization-or-mean-removal-and-variance-scaling

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import QuantileTransformer

scaler = RobustScaler().fit(wineX)
scaler = Normalizer().fit(wineX)
#scaler = QuantileTransformer(n_quantiles=10).fit(wineX)
scaler = StandardScaler(with_mean=True,with_std=True).fit(wineX)

# %%
stdWineX = scaler.transform(wineX)
pcaStdWineModel = PCA(n_components=kw).fit(stdWineX)
pcaStdWineMatrix = pd.DataFrame(pcaStdWineModel.components_.transpose(),columns=pcaWineCols)
print('PCA Transformation Matrix:\n')
display(pcaStdWineMatrix)
plt.figure(figsize=(5,5))
screePlot(plt,pcaStdWineModel.explained_variance_ratio_)
# Out:
# PCA Transformation Matrix:
#          pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0  -0.256929  0.261843  0.467486 -0.143964  0.165363 -0.030037  0.393435
# 1  -0.394931  0.105198 -0.279689 -0.080058  0.147774  0.382664  0.445111
# 2   0.146461  0.144093  0.588076  0.055510 -0.234621 -0.362248  0.047698
# 3   0.318905  0.342585 -0.075502  0.112456  0.507921  0.063317 -0.095763
# 4  -0.313450  0.269770  0.046769  0.165290 -0.393897  0.425442 -0.473296
# 5   0.422691  0.111179 -0.098998  0.303306 -0.248452  0.283180  0.362714
# 6   0.474420  0.143948 -0.101281  0.132232 -0.223967  0.106769  0.234813
# 7  -0.092438  0.554920 -0.051563  0.150579  0.330357 -0.154553  0.013286
# 8  -0.208070 -0.152922 -0.406787  0.471478 -0.001458 -0.560897  0.079321
# 9  -0.299852  0.119634  0.168691  0.588020 -0.193246  0.020141  0.170236
# 10 -0.058924 -0.492727  0.212931  0.080032  0.116023  0.169475  0.338906
# 11  0.087476 -0.296601  0.295838  0.472439  0.459129  0.277888 -0.273177
#
#          pc8       pc9      pc10      pc11      pc12
# 0  -0.001155 -0.424169  0.272432  0.276932 -0.335093
# 1  -0.310078  0.123233 -0.493946 -0.140799 -0.082421
# 2  -0.444962  0.246233 -0.330355 -0.229276  0.001347
# 3  -0.081945  0.488024  0.207174 -0.005144 -0.451215
# 4  -0.375532  0.044050  0.238873  0.193398 -0.043278
# 5  -0.120098 -0.301397  0.303448 -0.486158 -0.000905
# 6  -0.011279 -0.001814 -0.294780  0.720162  0.064063
# 7  -0.042944 -0.071081  0.076815  0.003324  0.715667
# 8  -0.362282 -0.136662  0.112409  0.139083 -0.206763
# 9   0.592221  0.297401 -0.085469 -0.047219 -0.078200
# 10 -0.226041  0.417060  0.416059  0.191289  0.332012
# 11 -0.093046 -0.356647 -0.307830  0.018082  0.008288
#     explained variance
# 0             0.253462
# 1             0.220821
# 2             0.136792
# 3             0.089052
# 4             0.070042
# 5             0.055033
# 6             0.046986
# 7             0.042999
# 8             0.038198
# 9             0.024918
# 10            0.018966
# 11            0.002732

# %%
stdWhiteWineX = scaler.transform(whiteWineX)
stdRedWineX = scaler.transform(redWineX)
pcaStdWhiteWineDataPD = pd.DataFrame(pcaStdWineModel.transform(stdWhiteWineX),columns=pcaWineCols)
pcaStdRedWineDataPD = pd.DataFrame(pcaStdWineModel.transform(stdRedWineX),columns=pcaWineCols)

# %% [markdown]
# It is observed that there are significant differences between both populations.

# %%
cols = ['pc1','pc2']
alpha=0.03
df=2
plt.figure(figsize=(14,14))
plt.axis([-7,7,-7,7])
getProbabilityDensityContour(plt,pcaStdWhiteWineDataPD,cols,alpha,df,color='Blue')
scatterPlot(plt,pcaStdWhiteWineDataPD,'pc1','pc2','Blue',color='Black',alpha=0.25)
getProbabilityDensityContour(plt,pcaStdRedWineDataPD,cols,alpha,df,color='Red')
scatterPlot(plt,pcaStdRedWineDataPD,'pc1','pc2','Red',color='Black',alpha=0.25)
plt.show()
